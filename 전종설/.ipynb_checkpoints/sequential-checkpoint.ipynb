# %% [markdown]
# # Set covering

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import math
import matplotlib.pyplot as plt

file_path = "weed_coordinates.txt"
data = pd.read_csv(file_path)
coordinates = pd.read_csv("xyz.csv",  index_col=0)

_z = []
for i in data.itertuples():
    cond = (coordinates['x'] == i.x) & (coordinates['y'] == i.y)
    item = coordinates.loc[cond, "z"]
    if len(item) == 0:
        v = 140
    else:
        v = float(item)
    _z.append(v)

data["z"] = _z

# 3d plot용
_points = [(row//10, col//10, hei//10) for row, col, hei in zip(data['x'], data['y'], data['z'])]
points = pd.DataFrame(_points, columns=['x', 'y', 'z'])
# Out:
# /var/folders/dj/c81zc2b12d54dz30fc1stjv80000gn/T/ipykernel_6929/444262361.py:18: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   v = float(item)

# %%
# iteration = [5-1,6-1]
iteration = [1,1]

_row = [0,100,200,300,400,500]
_col = [0,100,200,300,400,500,600]

drone_angle = math.radians(120)
t = math.tan(drone_angle / 2)

## 상공 10m~50m
def calc_range(height):
    # 방사각 120도 일때 반지름 범위

    drone_height = [height -5, height]
    r = [h * math.tan(drone_angle / 2) for h in drone_height]

    return r[0], r[-1]

_, r0 = calc_range(20)
r1, r2 = calc_range(15)

def solve_sc(row_index, col_index):
    solution = {"x": [], "y": [], "z": []}
    inf = dict()
    
    con1 = (_row[row_index]<= data['y']) & (data['y']<=_row[row_index+1])
    con2 = (_col[col_index]<= data['x']) & (data['x']<=_col[col_index+1])
    df = data[con1 & con2]
    df['y'] = [_r - 100 * row_index for _r in df['y'].values]
    df['x'] = [_c - 100 * col_index for _c in df['x'].values]

    con1 = (_row[row_index]<= coordinates['y']) & (coordinates['y']<=_row[row_index+1])
    con2 = (_col[col_index]<= coordinates['x']) & (coordinates['x']<=_col[col_index+1])
    space = coordinates[con1 & con2]


    # 'row'와 'col' 열을 이용하여 튜플 리스트 생성
    required_pixels = [(x, y, z) for x, y, z in zip(df['x'], df['y'], df['z'])]

    # 데이터/파라미터 초기화
    N = 100  # 그리드의 가로 크기
    M = 100  # 그리드의 세로 크기
    J = range(N * M)  # 전체 그리드 픽셀 집합
    I = [y * N + x for (x, y, z) in required_pixels]
    Zj = [z for z in space['z']]
    Zi = [z for (x,y,z) in required_pixels]


    # 높이 고려 안했을 때의 최대 거리
    max_distance = r0

    # 제약 조건을 추가하기 전에, 각 i 픽셀에 대해 허용 가능한 j 픽셀만 필터링
    nearby_j = {i: [j for j in J if math.sqrt(((divmod(j, N)[0]-divmod(i, N)[0])**2 + 
                                            (divmod(j, N)[1]-divmod(i, N)[1])**2)) <= max_distance] for i in I}
            
    # 모델 생성
    model = gp.Model("pesticide_application")

    # 변수 생성
    S = model.addVars(J, vtype=GRB.BINARY, name="S")  # 살포 지점 j가 선택되었는지를 나타내는 이진 변수
    C = model.addVars([(i, j) for i in I for j in nearby_j[i]], vtype=GRB.BINARY, name="C")  # 지점 j에 의해서 지점 i가 커버될 수 있는지를 나타내는 이진 변수
    a = model.addVars(J, vtype=GRB.CONTINUOUS, name="a")
    q = model.addVars(J, vtype=GRB.CONTINUOUS, name="q")

    # 목적 함수 설정: 최소한의 살포 지점 선택
    model.setObjective(gp.quicksum(S[j] for j in J), sense=GRB.MINIMIZE)

    # 제약 조건 추가
    index = 0
    for i in I:
        xi, yi = divmod(i, N)  # i 픽셀의 (x, y) 좌표
        zi = Zi[index]
        index += 1
        for j in nearby_j[i]:

            
            xj, yj = divmod(j, N)  # j 픽셀의 (x, y) 좌표
            zj = Zj[j]
            dist = math.sqrt(((xj-xi)**2 + (yj-yi)**2)) + t  # 두 좌표간의 거리

            # i 픽셀이 j 픽셀에 의해 커버될 수 있는지에 대한 제약 조건                      
            model.addConstr(dist * C[i,j]<=a[j])
            # model.addConstr(r1 <= a[j])
            model.addConstr(a[j]<= r2)
            model.addConstr(S[j] >= C[i, j])
            # if dist != 0:
            #     model.addConstr(q[j] == zj/dist * a[j])
            # else:

            # model.addConstr(q[j] == a[j] + t * (zi-zj))

    # 모든 i가 적어도 하나의 j에 의해 커버되어야 한다는 제약 조건
    for i in I:
        model.addConstr(gp.quicksum(C[i, j] for j in nearby_j[i]) >= 1)

    # 모델 최적화
    model.optimize()

    """여기부터 주석"""
    
    # 두 번째 모델 생성
    second_model = gp.Model("second_model")

    # 첫 번째 모델의 변수와 제약 조건을 복사
    S2 = second_model.addVars(J, vtype=GRB.BINARY, name="S")
    C2 = second_model.addVars([(i, j) for i in I for j in nearby_j[i]], vtype=GRB.BINARY, name="C")
    a2 = second_model.addVars(J, vtype=GRB.CONTINUOUS, name="a")

    # 첫 번째 모델의 솔루션 고정
    if model.status == GRB.OPTIMAL:
        for j in J:
            S[j].start = S[j].x
            a[j].start = a[j].x
        for i, j in C.keys():
            C[i, j].start = C[i, j].x

        # 첫 번째 모델의 솔루션을 두 번째 모델에 고정
        for j in J:
            S2[j].lb = S[j].x
            S2[j].ub = S[j].x

        for i, j in C.keys():
            C2[i, j].lb = C[i, j].x
            C2[i, j].ub = C[i, j].x
    else:
        inf["row_index"] = row_index
        inf['col_index'] = col_index

    # 두 번째 모델의 목적 함수 설정
    second_model.setObjective(gp.quicksum(a2[j] for j in J), sense=GRB.MINIMIZE)

    # 제약 조건 추가
    index = 0
    for i in I:
        xi, yi = divmod(i, N)
        zi = Zi[index]
        index += 1
        for j in nearby_j[i]:
            xj, yj = divmod(j, N)

            zj = Zj[j]
            dist = math.sqrt((xj - xi)**2 + (yj - yi)**2)
            second_model.addConstr(r1 <= a2[j])
            second_model.addConstr(dist * C2[i, j] <= a2[j])
            second_model.addConstr(a2[j] <= r2)

    # 모든 i가 적어도 하나의 j에 의해 커버되어야 한다는 제약 조건
    for i in I:
        second_model.addConstr(gp.quicksum(C2[i, j] for j in nearby_j[i]) >= 1)

    # 두 번째 모델 최적화
    second_model.optimize()

    # 최적해 출력 및 시각화 준비
    if second_model.status == GRB.OPTIMAL:
        # solution = {v.varName: v.x for v in model.getVars() if v.x != 0}

        # 시각화 코드
        fig, ax = plt.subplots(figsize=(12, 10))

        # 농약 살포가 필요한 픽셀
        for i in I:
            xi, yi = divmod(i, N)
            ax.scatter(xi, yi, color='red', marker='s', s=10)

        # 선택된 살포 지점 및 커버 범위
        for j in J:
            if S[j].x > 0.5:
                xj, yj = divmod(j, N)
                aj = a2[j].x
                rect = plt.Circle((xj, yj), radius=aj, color='blue', fill=False, linestyle='dotted')
                ax.add_artist(rect)
                ax.scatter(xj, yj, color='blue', marker='o', s=10)

                solution['x'].append(xj + row_index * 100)
                solution['y'].append(yj + col_index * 100)
                solution['z'].append(aj)

        C = {var.varName: var.X for var in second_model.getVars() if (var.varName[0] == "C") & (var.X != 0)}

        plt.xlim(-1, N)
        plt.ylim(-1, M)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.grid(True)
        plt.title('Pesticide Application Optimization with Varying Z Range')
        plt.xlabel('X Coordinate')
        plt.ylabel('Y Coordinate')
        plt.savefig(f"sc{row_index}_{col_index}")
    else:
        inf["row_index"] = row_index
        inf['col_index'] = col_index
        print("No optimal solution found.")

    """여기까지 주석"""

    return solution, inf, C

# %%
iteration = [5,6]
# iteration = [1,1]
_row = [0,100,200,300,400,500]
_col = [0,100,200,300,400,500,600]

solutions = []
infeasible = []
cluster = []

for row_index in range(iteration[0]):
    for col_index in range(iteration[1]):
        sol, inf, c = solve_sc(row_index, col_index)
        solutions.append(sol)
        infeasible.append(inf)
        cluster.append(c)
# Out:
# /var/folders/3l/z2_cjhyd20v1_yppby93tmnh0000gn/T/ipykernel_26634/777627153.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y'] = [_r - 100 * row_index for _r in df['y'].values]
# /var/folders/3l/z2_cjhyd20v1_yppby93tmnh0000gn/T/ipykernel_26634/777627153.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x'] = [_c - 100 * col_index for _c in df['x'].values]
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3850789 rows, 1313423 columns and 7700348 nonzeros
# Model fingerprint: 0x51cbcbc3
# Variable types: 20000 continuous, 1293423 integer (1293423 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 409.0000000
# Presolve removed 2788488 rows and 247646 columns (presolve time = 6s) ...
# Presolve removed 2940842 rows and 400000 columns (presolve time = 10s) ...
# Presolve removed 3160842 rows and 620000 columns (presolve time = 15s) ...
# Presolve removed 3380842 rows and 840000 columns (presolve time = 20s) ...
# Presolve removed 3660842 rows and 1120000 columns (presolve time = 25s) ...
# Presolve removed 3850390 rows and 1309398 columns (presolve time = 30s) ...
# Presolve removed 3850789 rows and 1313423 columns
# Presolve time: 31.69s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 32.85 seconds (16.48 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 409
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3850789 rows, 1303423 columns and 6416925 nonzeros
# Model fingerprint: 0xf8b71af0
# Variable types: 10000 continuous, 1293423 integer (1293423 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3850789 rows and 1303423 columns
# Presolve time: 2.34s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.91 seconds (2.12 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 78497.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.849760686726e+04, best bound 7.849760686726e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3187664 rows, 1092441 columns and 6374449 nonzeros
# Model fingerprint: 0x8d7d0028
# Variable types: 20000 continuous, 1072441 integer (1072441 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 253.0000000
# Presolve removed 2660637 rows and 560000 columns (presolve time = 5s) ...
# Presolve removed 3187354 rows and 1089638 columns (presolve time = 10s) ...
# Presolve removed 3187664 rows and 1092441 columns
# Presolve time: 10.95s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 11.95 seconds (7.96 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 253
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3187664 rows, 1082441 columns and 5312008 nonzeros
# Model fingerprint: 0x4e8f7a7c
# Variable types: 10000 continuous, 1072441 integer (1072441 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3187664 rows and 1082441 columns
# Presolve time: 1.90s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.38 seconds (1.73 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 137958
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.379578468229e+05, best bound 1.379578468229e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2640985 rows, 910230 columns and 5281380 nonzeros
# Model fingerprint: 0x334ea1a3
# Variable types: 20000 continuous, 890230 integer (890230 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 275.0000000
# Presolve removed 1894219 rows and 160000 columns (presolve time = 5s) ...
# Presolve removed 2254219 rows and 520000 columns (presolve time = 10s) ...
# Presolve removed 2640676 rows and 906457 columns (presolve time = 15s) ...
# Presolve removed 2640985 rows and 910230 columns
# Presolve time: 17.69s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 18.37 seconds (11.30 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 275
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2640985 rows, 900230 columns and 4401150 nonzeros
# Model fingerprint: 0x067d8fec
# Variable types: 10000 continuous, 890230 integer (890230 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2640985 rows and 900230 columns
# Presolve time: 1.46s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.82 seconds (1.41 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 74893.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.489387691928e+04, best bound 7.489387691928e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1342006 rows, 477288 columns and 2683717 nonzeros
# Model fingerprint: 0x2340900e
# Variable types: 20000 continuous, 457288 integer (457288 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 126.0000000
# Presolve removed 1342006 rows and 477288 columns
# Presolve time: 4.93s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 5.25 seconds (3.53 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 126
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1342006 rows, 467288 columns and 2236429 nonzeros
# Model fingerprint: 0xa7dea873
# Variable types: 10000 continuous, 457288 integer (457288 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1342006 rows and 467288 columns
# Presolve time: 0.73s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.92 seconds (0.67 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 74686
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.468603082237e+04, best bound 7.468603082237e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 953463 rows, 347781 columns and 1906617 nonzeros
# Model fingerprint: 0x867db866
# Variable types: 20000 continuous, 327781 integer (327781 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 953463 rows and 347781 columns
# Presolve time: 1.72s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.09 seconds (1.59 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 953463 rows, 337781 columns and 1588836 nonzeros
# Model fingerprint: 0x18c093af
# Variable types: 10000 continuous, 327781 integer (327781 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 953463 rows and 337781 columns
# Presolve time: 0.49s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.63 seconds (0.47 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 61375.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.137510411591e+04, best bound 6.137510411591e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5492363 rows, 1860570 columns and 10983106 nonzeros
# Model fingerprint: 0x0cd89be9
# Variable types: 20000 continuous, 1840570 integer (1840570 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 316.0000000
# Presolve removed 4721267 rows and 1085332 columns (presolve time = 5s) ...
# Presolve removed 4775935 rows and 1140000 columns (presolve time = 10s) ...
# Presolve removed 5195935 rows and 1560000 columns (presolve time = 15s) ...
# Presolve removed 5492266 rows and 1860294 columns (presolve time = 20s) ...
# Presolve removed 5492363 rows and 1860570 columns
# Presolve time: 21.94s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 24.23 seconds (20.30 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 4 316
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5492363 rows, 1850570 columns and 9152536 nonzeros
# Model fingerprint: 0x96281acb
# Variable types: 10000 continuous, 1840570 integer (1840570 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 5492363 rows and 1850570 columns
# Presolve time: 3.54s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 4.71 seconds (3.10 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 136603
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.366032311686e+05, best bound 1.366032311686e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3742928 rows, 1277487 columns and 7484662 nonzeros
# Model fingerprint: 0x0f9f3bfd
# Variable types: 20000 continuous, 1257487 integer (1257487 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3119537 rows and 650000 columns (presolve time = 5s) ...
# Presolve removed 3729537 rows and 1260000 columns (presolve time = 10s) ...
# Presolve removed 3742928 rows and 1277487 columns
# Presolve time: 12.99s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 14.32 seconds (10.25 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3742928 rows, 1267487 columns and 6237175 nonzeros
# Model fingerprint: 0xeb00b56b
# Variable types: 10000 continuous, 1257487 integer (1257487 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3742928 rows and 1267487 columns
# Presolve time: 2.09s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.61 seconds (2.06 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 117805
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.178053007109e+05, best bound 1.178053007109e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3122254 rows, 1070634 columns and 6243672 nonzeros
# Model fingerprint: 0xf262fa1b
# Variable types: 20000 continuous, 1050634 integer (1050634 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 163.0000000
# Presolve removed 2822858 rows and 764849 columns (presolve time = 5s) ...
# Presolve removed 3122254 rows and 1070634 columns
# Presolve time: 8.99s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 10.00 seconds (10.93 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 3 163
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3122254 rows, 1060634 columns and 5203038 nonzeros
# Model fingerprint: 0xef69e1aa
# Variable types: 10000 continuous, 1050634 integer (1050634 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3122254 rows and 1060634 columns
# Presolve time: 1.61s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.03 seconds (1.70 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 147672
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.476720825881e+05, best bound 1.476720825881e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3662252 rows, 1250611 columns and 7323510 nonzeros
# Model fingerprint: 0x6b3f89fb
# Variable types: 20000 continuous, 1230611 integer (1230611 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 178.0000000
# Presolve removed 3044907 rows and 630000 columns (presolve time = 5s) ...
# Presolve removed 3354907 rows and 940000 columns (presolve time = 10s) ...
# Presolve removed 3661807 rows and 1246900 columns (presolve time = 15s) ...
# Presolve removed 3662252 rows and 1250611 columns
# Presolve time: 16.33s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 17.43 seconds (10.86 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 178
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3662252 rows, 1240611 columns and 6102899 nonzeros
# Model fingerprint: 0x682ff5ff
# Variable types: 10000 continuous, 1230611 integer (1230611 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3662252 rows and 1240611 columns
# Presolve time: 1.97s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.48 seconds (2.01 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 81206.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.120677521543e+04, best bound 8.120677521543e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7023243 rows, 2370822 columns and 14044450 nonzeros
# Model fingerprint: 0x9848cb85
# Variable types: 20000 continuous, 2350822 integer (2350822 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 410.0000000
# Presolve removed 5922665 rows and 1264826 columns (presolve time = 5s) ...
# Presolve removed 5927839 rows and 1270000 columns (presolve time = 10s) ...
# Presolve removed 6187839 rows and 1530000 columns (presolve time = 15s) ...
# Presolve removed 6527839 rows and 1870000 columns (presolve time = 20s) ...
# Presolve removed 6957839 rows and 2300000 columns (presolve time = 25s) ...
# Presolve removed 7023243 rows and 2370822 columns (presolve time = 30s) ...
# Presolve removed 7023243 rows and 2370822 columns
# Presolve time: 30.60s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 32.99 seconds (23.05 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 410
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7023243 rows, 2360822 columns and 11703628 nonzeros
# Model fingerprint: 0xde63fea4
# Variable types: 10000 continuous, 2350822 integer (2350822 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 7023243 rows and 2360822 columns
# Presolve time: 4.36s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 6.23 seconds (4.03 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 142400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.424001888791e+05, best bound 1.424001888791e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2710758 rows, 933482 columns and 5420783 nonzeros
# Model fingerprint: 0xbad2890e
# Variable types: 20000 continuous, 913482 integer (913482 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 173.0000000
# Presolve removed 2481795 rows and 700000 columns (presolve time = 5s) ...
# Presolve removed 2710758 rows and 933482 columns
# Presolve time: 7.96s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 8.77 seconds (6.50 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 173
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2710758 rows, 923482 columns and 4517301 nonzeros
# Model fingerprint: 0xb817bb4e
# Variable types: 10000 continuous, 913482 integer (913482 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2710758 rows and 923482 columns
# Presolve time: 1.53s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.04 seconds (1.45 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 117855
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.178554580695e+05, best bound 1.178554580695e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2126773 rows, 738825 columns and 4252950 nonzeros
# Model fingerprint: 0x6444a1e2
# Variable types: 20000 continuous, 718825 integer (718825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2126773 rows and 738825 columns (presolve time = 5s) ...
# Presolve removed 2126773 rows and 738825 columns
# Presolve time: 5.35s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 6.35 seconds (5.12 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2126773 rows, 728825 columns and 3544125 nonzeros
# Model fingerprint: 0x50540515
# Variable types: 10000 continuous, 718825 integer (718825 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2126773 rows and 728825 columns
# Presolve time: 1.13s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.44 seconds (1.12 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 64484.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.448415511845e+04, best bound 6.448415511845e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1895117 rows, 661593 columns and 3789370 nonzeros
# Model fingerprint: 0x59658efe
# Variable types: 20000 continuous, 641593 integer (641593 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 209.0000000
# Presolve removed 1895117 rows and 661593 columns (presolve time = 5s) ...
# Presolve removed 1895117 rows and 661593 columns
# Presolve time: 5.07s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 5.58 seconds (3.96 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 209
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1895117 rows, 651593 columns and 3157777 nonzeros
# Model fingerprint: 0x25b25cbf
# Variable types: 10000 continuous, 641593 integer (641593 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1895117 rows and 651593 columns
# Presolve time: 1.04s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.41 seconds (0.99 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 90452.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.045230437537e+04, best bound 9.045230437537e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3035202 rows, 1041612 columns and 6069382 nonzeros
# Model fingerprint: 0x0ac424f9
# Variable types: 20000 continuous, 1021612 integer (1021612 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 133.0000000
# Presolve removed 2726979 rows and 730000 columns (presolve time = 5s) ...
# Presolve removed 3034918 rows and 1040175 columns (presolve time = 10s) ...
# Presolve removed 3035202 rows and 1041612 columns
# Presolve time: 10.86s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 11.63 seconds (8.62 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 133
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3035202 rows, 1031612 columns and 5057770 nonzeros
# Model fingerprint: 0xd0a0e001
# Variable types: 10000 continuous, 1021612 integer (1021612 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3035202 rows and 1031612 columns
# Presolve time: 1.51s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.92 seconds (1.65 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 114201
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.142008308655e+05, best bound 1.142008308655e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4496097 rows, 1528554 columns and 8990910 nonzeros
# Model fingerprint: 0x8696af80
# Variable types: 20000 continuous, 1508554 integer (1508554 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 301.0000000
# Presolve removed 3366475 rows and 394600 columns (presolve time = 6s) ...
# Presolve removed 3531875 rows and 560000 columns (presolve time = 10s) ...
# Presolve removed 3781875 rows and 810000 columns (presolve time = 15s) ...
# Presolve removed 4071875 rows and 1100000 columns (presolve time = 20s) ...
# Presolve removed 4411875 rows and 1440000 columns (presolve time = 25s) ...
# Presolve removed 4495662 rows and 1524801 columns (presolve time = 30s) ...
# Presolve removed 4495662 rows and 1524801 columns (presolve time = 35s) ...
# Sparsify removed 665204 nonzeros (89%)
# Presolve removed 4495662 rows and 1524504 columns
# Presolve time: 37.94s
# Presolved: 435 rows, 4050 columns, 84270 nonzeros
# Found heuristic solution: objective 46.0000000
# Variable types: 0 continuous, 4050 integer (3753 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.625000e+00   0.000000e+00     39s
#       51    1.0000000e+00   0.000000e+00   0.000000e+00     39s
#
# Root relaxation: objective 1.000000e+00, 51 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0000000    1.00000  0.00%     -   39s
#
# Explored 1 nodes (51 simplex iterations) in 39.34 seconds (24.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1 46 301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4496097 rows, 1518554 columns and 7492356 nonzeros
# Model fingerprint: 0x97903f55
# Variable types: 10000 continuous, 1508554 integer (1508554 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 4496097 rows and 1518554 columns
# Presolve time: 2.74s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 3.58 seconds (2.50 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 98352.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.835223088487e+04, best bound 9.835223088487e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2483155 rows, 857602 columns and 4965392 nonzeros
# Model fingerprint: 0x2d2faeac
# Variable types: 20000 continuous, 837602 integer (837602 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 281.0000000
# Presolve removed 1949602 rows and 320000 columns (presolve time = 5s) ...
# Presolve removed 2359602 rows and 730000 columns (presolve time = 10s) ...
# Presolve removed 2483155 rows and 857602 columns
# Presolve time: 13.06s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 13.72 seconds (8.39 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 281
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2483155 rows, 847602 columns and 4137790 nonzeros
# Model fingerprint: 0xcdd13215
# Variable types: 10000 continuous, 837602 integer (837602 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2483155 rows and 847602 columns
# Presolve time: 1.37s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.78 seconds (1.32 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 84826.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.482670263614e+04, best bound 8.482670263614e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 609971 rows, 233290 columns and 1219740 nonzeros
# Model fingerprint: 0xd21a4243
# Variable types: 20000 continuous, 213290 integer (213290 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 609971 rows and 233290 columns
# Presolve time: 0.76s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.02 seconds (0.83 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 609971 rows, 223290 columns and 1016450 nonzeros
# Model fingerprint: 0xd23d447e
# Variable types: 10000 continuous, 213290 integer (213290 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 609971 rows and 223290 columns
# Presolve time: 0.37s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.47 seconds (0.29 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 87813.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.781373140408e+04, best bound 8.781373140408e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2576023 rows, 888543 columns and 5151258 nonzeros
# Model fingerprint: 0x3a36412d
# Variable types: 20000 continuous, 868543 integer (868543 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2575955 rows and 888483 columns (presolve time = 5s) ...
# Presolve removed 2575955 rows and 888483 columns
# Presolve time: 5.43s
# Presolved: 68 rows, 60 columns, 1785 nonzeros
# Variable types: 0 continuous, 60 integer (60 binary)
# Found heuristic solution: objective 6.0000000
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   6.800000e+01   0.000000e+00      6s
#       15    5.0000000e+00   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 5.000000e+00, 15 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.0000000    5.00000  0.00%     -    6s
#
# Explored 1 nodes (15 simplex iterations) in 6.66 seconds (4.61 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 5 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+00, best bound 5.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2576023 rows, 878543 columns and 4292715 nonzeros
# Model fingerprint: 0x4c77f558
# Variable types: 10000 continuous, 868543 integer (868543 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2576023 rows and 878543 columns
# Presolve time: 1.52s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.88 seconds (1.38 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 113830
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.138301473583e+05, best bound 1.138301473583e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1532169 rows, 540643 columns and 3063801 nonzeros
# Model fingerprint: 0x592c2976
# Variable types: 20000 continuous, 520643 integer (520643 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 149.0000000
# Presolve removed 1532169 rows and 540643 columns
# Presolve time: 4.69s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 5.22 seconds (3.54 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 149
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1532169 rows, 530643 columns and 2553158 nonzeros
# Model fingerprint: 0xfa333ec1
# Variable types: 10000 continuous, 520643 integer (520643 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1532169 rows and 530643 columns
# Presolve time: 0.73s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.95 seconds (0.79 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 75266.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.526622932433e+04, best bound 7.526622932433e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2725793 rows, 938488 columns and 5450889 nonzeros
# Model fingerprint: 0xf7c1b78e
# Variable types: 20000 continuous, 918488 integer (918488 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 275.0000000
# Presolve removed 2180518 rows and 390000 columns (presolve time = 5s) ...
# Presolve removed 2560518 rows and 770000 columns (presolve time = 10s) ...
# Presolve removed 2725793 rows and 938488 columns
# Presolve time: 14.42s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 15.12 seconds (9.36 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 275
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2725793 rows, 928488 columns and 4542401 nonzeros
# Model fingerprint: 0x4eb1eaf7
# Variable types: 10000 continuous, 918488 integer (918488 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2725793 rows and 928488 columns
# Presolve time: 1.50s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.89 seconds (1.46 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 69749.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.974968602080e+04, best bound 6.974968602080e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2635482 rows, 908398 columns and 5270291 nonzeros
# Model fingerprint: 0x981cfc71
# Variable types: 20000 continuous, 888398 integer (888398 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2619886 rows and 890000 columns (presolve time = 5s) ...
# Presolve removed 2635482 rows and 908398 columns
# Presolve time: 6.83s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 7.99 seconds (5.92 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2635482 rows, 898398 columns and 4391893 nonzeros
# Model fingerprint: 0x89c2a479
# Variable types: 10000 continuous, 888398 integer (888398 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2635482 rows and 898398 columns
# Presolve time: 1.41s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.75 seconds (1.41 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 80869.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.086933634785e+04, best bound 8.086933634785e+04, gap 0.0000%
# /var/folders/3l/z2_cjhyd20v1_yppby93tmnh0000gn/T/ipykernel_26634/777627153.py:159: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(12, 10))
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1644357 rows, 578037 columns and 3288222 nonzeros
# Model fingerprint: 0xb9428d22
# Variable types: 20000 continuous, 558037 integer (558037 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 77.0000000
# Presolve removed 1644357 rows and 578037 columns
# Presolve time: 3.07s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 3.72 seconds (3.02 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 3 77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.000000000000e+00, best bound 3.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1644357 rows, 568037 columns and 2740185 nonzeros
# Model fingerprint: 0x1a15546f
# Variable types: 10000 continuous, 558037 integer (558037 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1644357 rows and 568037 columns
# Presolve time: 0.80s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.02 seconds (0.85 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 106692
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.066918919028e+05, best bound 1.066918919028e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5515871 rows, 1868447 columns and 11030521 nonzeros
# Model fingerprint: 0x357bf76a
# Variable types: 20000 continuous, 1848447 integer (1848447 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 301.0000000
# Presolve removed 4664277 rows and 1010607 columns (presolve time = 5s) ...
# Presolve removed 4813670 rows and 1160000 columns (presolve time = 10s) ...
# Presolve removed 5133670 rows and 1480000 columns (presolve time = 15s) ...
# Presolve removed 5515291 rows and 1861621 columns (presolve time = 20s) ...
# Presolve removed 5515871 rows and 1868447 columns
# Presolve time: 22.32s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 24.23 seconds (14.99 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5515871 rows, 1858447 columns and 9192074 nonzeros
# Model fingerprint: 0x18dd80ae
# Variable types: 10000 continuous, 1848447 integer (1848447 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 5515871 rows and 1858447 columns
# Presolve time: 3.67s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 4.51 seconds (3.11 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 146531
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.465313052819e+05, best bound 1.465313052819e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9141508 rows, 3076878 columns and 18280843 nonzeros
# Model fingerprint: 0x8adeb01d
# Variable types: 20000 continuous, 3056878 integer (3056878 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 538.0000000
# Presolve removed 5756548 rows and 12074 columns (presolve time = 5s) ...
# Presolve removed 7309212 rows and 1238124 columns (presolve time = 10s) ...
# Presolve removed 7401088 rows and 1330000 columns (presolve time = 15s) ...
# Presolve removed 7661088 rows and 1590000 columns (presolve time = 20s) ...
# Presolve removed 7931088 rows and 1860000 columns (presolve time = 25s) ...
# Presolve removed 8221088 rows and 2150000 columns (presolve time = 30s) ...
# Presolve removed 8411088 rows and 2340000 columns (presolve time = 35s) ...
# Presolve removed 8601088 rows and 2530000 columns (presolve time = 40s) ...
# Presolve removed 8811088 rows and 2740000 columns (presolve time = 45s) ...
# Presolve removed 9081088 rows and 3010000 columns (presolve time = 50s) ...
# Presolve removed 9140270 rows and 3069182 columns (presolve time = 55s) ...
# Presolve removed 9141508 rows and 3076878 columns
# Presolve time: 59.57s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 62.54 seconds (38.51 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 2 538
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 9141508 rows, 3066878 columns and 15233965 nonzeros
# Model fingerprint: 0x4ae28541
# Variable types: 10000 continuous, 3056878 integer (3056878 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 9141508 rows and 3066878 columns (presolve time = 5s) ...
# Presolve removed 9141508 rows and 3066878 columns
# Presolve time: 6.25s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 7.66 seconds (5.33 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 155261
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.552605689744e+05, best bound 1.552605689744e+05, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1988632 rows, 692772 columns and 3976617 nonzeros
# Model fingerprint: 0xe7088c45
# Variable types: 20000 continuous, 672772 integer (672772 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 48.0000000
# Presolve removed 1857689 rows and 560000 columns (presolve time = 5s) ...
# Presolve removed 1988632 rows and 692772 columns
# Presolve time: 7.29s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 7.96 seconds (6.04 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 48
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1988632 rows, 682772 columns and 3313845 nonzeros
# Model fingerprint: 0x141fb2b7
# Variable types: 10000 continuous, 672772 integer (672772 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1988632 rows and 682772 columns
# Presolve time: 1.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.41 seconds (1.04 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 53476.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.347658301914e+04, best bound 5.347658301914e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1187020 rows, 425614 columns and 2373521 nonzeros
# Model fingerprint: 0x92d4249e
# Variable types: 20000 continuous, 405614 integer (405614 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 175.0000000
# Presolve removed 1187020 rows and 425614 columns
# Presolve time: 4.05s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 4.44 seconds (2.90 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 175
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1187020 rows, 415614 columns and 1977907 nonzeros
# Model fingerprint: 0x594e6503
# Variable types: 10000 continuous, 405614 integer (405614 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 1187020 rows and 415614 columns
# Presolve time: 0.62s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.80 seconds (0.59 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 51831.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.183156248773e+04, best bound 5.183156248773e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3722604 rows, 1270694 columns and 7443884 nonzeros
# Model fingerprint: 0xdb7e20a1
# Variable types: 20000 continuous, 1250694 integer (1250694 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 315.0000000
# Presolve removed 3280692 rows and 827071 columns (presolve time = 5s) ...
# Presolve removed 3423621 rows and 970000 columns (presolve time = 10s) ...
# Presolve removed 3683621 rows and 1230000 columns (presolve time = 15s) ...
# Sparsify removed 93879 nonzeros (90%)
# Presolve removed 3722370 rows and 1269382 columns
# Presolve time: 18.92s
# Presolved: 234 rows, 1312 columns, 10840 nonzeros
# Found heuristic solution: objective 69.0000000
# Variable types: 32 continuous, 1280 integer (1155 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.250000e-01   0.000000e+00     20s
#        2    1.0000000e+00   0.000000e+00   0.000000e+00     20s
#
# Root relaxation: objective 1.000000e+00, 2 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0000000    1.00000  0.00%     -   20s
#
# Explored 1 nodes (2 simplex iterations) in 20.56 seconds (17.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1 69 315
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 3722604 rows, 1260694 columns and 6203190 nonzeros
# Model fingerprint: 0x2f4287c6
# Variable types: 10000 continuous, 1250694 integer (1250694 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 3722604 rows and 1260694 columns
# Presolve time: 2.05s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 2.56 seconds (2.05 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 66150.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.615031536111e+04, best bound 6.615031536111e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2219362 rows, 769698 columns and 4438188 nonzeros
# Model fingerprint: 0xc7cf6c08
# Variable types: 20000 continuous, 749698 integer (749698 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 245.0000000
# Presolve removed 1762950 rows and 310000 columns (presolve time = 5s) ...
# Presolve removed 2219069 rows and 766119 columns (presolve time = 10s) ...
# Presolve removed 2219362 rows and 769698 columns
# Presolve time: 11.92s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 12.48 seconds (8.07 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 245
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2219362 rows, 759698 columns and 3698490 nonzeros
# Model fingerprint: 0x9484bb2b
# Variable types: 10000 continuous, 749698 integer (749698 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 3e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2219362 rows and 759698 columns
# Presolve time: 1.20s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.50 seconds (1.17 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 70165.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.016537821462e+04, best bound 7.016537821462e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2678998 rows, 922887 columns and 5357212 nonzeros
# Model fingerprint: 0x4eae3560
# Variable types: 20000 continuous, 902887 integer (902887 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective 277.0000000
# Presolve removed 1949274 rows and 190000 columns (presolve time = 5s) ...
# Presolve removed 2269274 rows and 510000 columns (presolve time = 10s) ...
# Presolve removed 2639274 rows and 880000 columns (presolve time = 15s) ...
# Presolve removed 2678998 rows and 922887 columns
# Presolve time: 18.76s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 19.47 seconds (12.18 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 1 277
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2678998 rows, 912887 columns and 4464325 nonzeros
# Model fingerprint: 0x8eeac3ad
# Variable types: 10000 continuous, 902887 integer (902887 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 2678998 rows and 912887 columns
# Presolve time: 1.33s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.83 seconds (1.44 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 66025.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.602577678453e+04, best bound 6.602577678453e+04, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 708729 rows, 266203 columns and 1417218 nonzeros
# Model fingerprint: 0x68a16586
# Variable types: 20000 continuous, 246203 integer (246203 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 708729 rows and 266203 columns
# Presolve time: 1.01s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 1.31 seconds (1.12 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i5-8279U CPU @ 2.40GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 708729 rows, 256203 columns and 1181015 nonzeros
# Model fingerprint: 0x6c7ee3aa
# Variable types: 10000 continuous, 246203 integer (246203 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Presolve removed 708729 rows and 256203 columns
# Presolve time: 0.35s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.45 seconds (0.34 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 86878.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.687890571399e+04, best bound 8.687890571399e+04, gap 0.0000%

# %%
# j에 속하는 i들을 분류하는 함수
def classify_by_j(data):
    result = {}
    for key in data.keys():
        i, j = map(int, key[2:-1].split(','))
        if j not in result:
            result[j] = []
        result[j].append(i)
    return result

# 정규 표현식을 사용하여 문자열에서 숫자 추출
cluster_list = []
for c in cluster:
    cluster_list.append(classify_by_j(c))

N = 100
M = 100
# 시각화 코드
colors = [
    '#1F77B4', '#FF7F0E', '#2CA02C', '#D62728', '#9467BD',
    '#8C564B', '#E377C2', '#7F7F7F', '#BCBD22', '#17BECF'
]
c_index = 0
p_index = 0
for c in cluster_list:
    fig, ax = plt.subplots(figsize=(12, 10))

    for j, I in c.items():
        xj, yj = divmod(j, N)
        ax.scatter(xj, yj, color=colors[c_index % 10], marker='s', s=20)

        for i in I:
            xi, yi = divmod(i, N)
            ax.scatter(xi, yi, color=colors[c_index % 10], marker='o', s=10)

        c_index += 1

    plt.xlim(-1, N)
    plt.ylim(-1, M)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.grid(True)
    plt.title('Pesticide Application Optimization with Varying Z Range')
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.savefig(f"cluster{p_index}")
    plt.close()

    p_index += 1

# %%
scSol = pd.DataFrame({"x": [0], "y": [0], "z":[0]})
for sol in solutions:
    scSol = pd.concat([scSol, pd.DataFrame(sol)], axis=0, ignore_index=True)

scSol['z'] = [z/t for z in scSol['z']]

newz = []
for row in scSol.itertuples():
    con1 = (coordinates['x'] == row.y)
    con2 = (coordinates['y'] == row.x)

    p = coordinates.loc[con1 & con2, 'z'].values 
    newz.append(float(row.z + p /10))
scSol['z'] = newz

scSol.to_csv("sc_solutions.csv")
# Out:
# /var/folders/3l/z2_cjhyd20v1_yppby93tmnh0000gn/T/ipykernel_26634/2916735542.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   newz.append(float(row.z + p /10))

# %% [markdown]
# # Routing

# %%
def calculate_distances(df):
    # 노드의 수를 구합니다.
    num_nodes = len(df)
    
    # 거리를 저장할 데이터프레임을 생성합니다.
    distances = pd.DataFrame(np.zeros((num_nodes, num_nodes)), columns=df.index, index=df.index)
    
    # 모든 노드 쌍에 대해 거리를 계산합니다.
    for i in range(num_nodes):
        for j in range(i+1, num_nodes):
            # 두 노드 간의 유클리드 거리를 계산합니다.
            distance = np.sqrt((df.iloc[i]['x'] - df.iloc[j]['x'])**2 + 
                               (df.iloc[i]['y'] - df.iloc[j]['y'])**2 + 
                               (df.iloc[i]['z'] - df.iloc[j]['z'])**2)
            distances.iloc[i, j] = distance
            distances.iloc[j, i] = distance
    
    return distances

# 데이터프레임
file_name = "sc_solutions.csv"
nodes = pd.read_csv(file_name, sep=',', index_col=0)

# 각 노드 간의 거리 계산
distances = calculate_distances(nodes)
distances.to_csv("dist.csv")

selected = nodes[["x", "y"]]
selected.to_csv("selected.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
import pandas as pd

max_distance = 1600  # 5km

def create_data_model(distances, coordinates):
    data = {}
    
    """데이터 모델을 생성합니다."""
    dist_matrix = distances.values.tolist()
    data['distance_matrix'] = dist_matrix

    coord_matrix = coordinates.values.tolist()
    data['locations'] = coord_matrix

    data['num_vehicles'] = 15
    data['depot'] = 0

    return data

def solve():
    """VRP 문제를 설정하고 해결합니다."""
    coord = pd.read_csv("selected.csv", sep=',', index_col=0)
    dist =pd.read_csv("dist.csv", index_col=0)
    data = create_data_model(dist, coord)

    # 노드 수, 차량 수, 출발/도착 지점을 설정
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']), data['num_vehicles'], data['depot'])

    # 경로 모델 생성
    routing = pywrapcp.RoutingModel(manager)

    def distance_callback(from_index, to_index):
        """두 노드 간의 거리를 계산하는 콜백 함수"""
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    # 거리 콜백 함수 등록
    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # 비용 함수 설정
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # 거리 차원 생성
    dimension_name = 'Distance'
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        max_distance,  # 각 차량의 최대 이동 거리
        True,  # start cumul to zero
        dimension_name)
    
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(0)

    # 탐색 매개변수 설정
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    # 다양한 첫 번째 솔루션 전략 시도
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    # search_parameters.time_limit.seconds = 300
    search_parameters.solution_limit = 1000
    # 로그 출력을 비활성화
    search_parameters.log_search = True

    # 문제 해결
    solution = routing.SolveWithParameters(search_parameters)

    return manager, routing, solution, distance_dimension, data

def print_solution(manager, routing, solution, distance_dimension, data):
    """해결책을 출력하고 시각화합니다."""
    print('Objective: {}'.format(solution.ObjectiveValue()))
    total_distance = 0
    routes = []
    for vehicle_id in range(routing.vehicles()):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route = []
        route_distance = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route.append(node_index)
            plan_output += ' {} ->'.format(node_index)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(previous_index, index, vehicle_id)
        node_index = manager.IndexToNode(index)
        route.append(node_index)
        plan_output += ' {}\n'.format(node_index)
        plan_output += 'Distance of the route: {}km\n'.format(route_distance)
        print(plan_output)
        routes.append(route)
        total_distance += route_distance
    print('Total distance of all routes: {}km'.format(total_distance))

    return routes

def plot_routes(locations, routes):
    import matplotlib.pyplot as plt
    """경로를 시각화합니다."""
    plt.figure(figsize=(12, 8))
    colors = cm.rainbow(np.linspace(0, 1, len(routes)))
    for route, color in zip(routes, colors):
        x_coords = [locations[node][0] for node in route]
        y_coords = [locations[node][1] for node in route]
        for i in range(len(route) - 1):
            plt.quiver(x_coords[i], y_coords[i], x_coords[i + 1] - x_coords[i], y_coords[i + 1] - y_coords[i],
                        angles='xy', scale_units='xy', scale=1, color=color, width=0.003)
        for i, node in enumerate(route):
            plt.text(locations[node][0], locations[node][1], str(node), fontsize=12, ha='right')
    plt.xlabel('X coordinate')
    plt.ylabel('Y coordinate')
    plt.title('Vehicle Routes')
    plt.grid()
    plt.show()

def plot_individual_routes(locations, routes):
    _routes = routes
        
    """경로를 시각화합니다."""
    num_routes = len(_routes)
    fig, axes = plt.subplots(1, num_routes, figsize=(20, 5))
    colors = cm.rainbow(np.linspace(0, 1, num_routes))

    for ax, route, color in zip(axes, _routes, colors):
        x_coords = [locations[node][0] for node in route]
        y_coords = [locations[node][1] for node in route]
        for i in range(len(route) - 1):
            ax.quiver(x_coords[i], y_coords[i], x_coords[i + 1] - x_coords[i], y_coords[i + 1] - y_coords[i],
                        angles='xy', scale_units='xy', scale=1, color=color, width=0.003)
        for i, node in enumerate(route):
            ax.text(locations[node][0], locations[node][1], str(node), fontsize=12, ha='right')
        ax.set_xlabel('X coordinate')
        ax.set_ylabel('Y coordinate')
        ax.set_title(f'Vehicle {_routes.index(route)}')
        ax.grid()

    plt.suptitle('Vehicle Routes')
    plt.show()

    return _routes

# %%
manager, routing, solution, distance_dimension, data = solve()

if solution:
    routes = print_solution(manager, routing, solution, distance_dimension, data)
else:
    print("No solution found!")

# 경로 시각화
plot_routes(data['locations'], routes)
# Out:
# I0000 00:00:1717653962.453486   94576 search.cc:285] Start search (memory used = 205.80 MB)
# I0000 00:00:1717653962.453688   94576 search.cc:285] Root node processed (time = 0 ms, constraints = 450, memory used = 205.80 MB)
# I0000 00:00:1717653962.464931   94576 search.cc:285] Solution #0 (8857, time = 11 ms, branches = 34, failures = 1, depth = 33, memory used = 206.17 MB, limit = 0%)
# I0000 00:00:1717653962.468248   94576 search.cc:285] Solution #1 (8856, maximum = 8857, time = 14 ms, branches = 38, failures = 3, depth = 33, Relocate<1>, neighbors = 340, filtered neighbors = 1, accepted neighbors = 1, memory used = 206.29 MB, limit = 0%)

#  0 -> 0
# Distance of the route: 0km
#
# Route for vehicle 12:
#  0 -> 3 -> 4 -> 18 -> 21 -> 38 -> 36 -> 37 -> 35 -> 23 -> 22 -> 10 -> 7 -> 8 -> 9 -> 20 -> 6 -> 5 -> 2 -> 0
# Distance of the route: 1515km
#
# Route for vehicle 13:
#  0 -> 0
# Distance of the route: 0km
#
# Route for vehicle 14:
#  0 -> 0
# Distance of the route: 0km
#
# Total distance of all routes: 5972km
# I0000 00:00:1717654003.642612   94576 search.cc:285] Solution #998 (6498, minimum = 5972, maximum = 8857, time = 41189 ms, branches = 5742, failures = 2540, depth = 33, Relocate<1>, neighbors = 3380188, filtered neighbors = 998, accepted neighbors = 998, memory used = 206.64 MB, limit = 99%)
# I0000 00:00:1717654003.644694   94576 search.cc:285] Solution #999 (6499, minimum = 5972, maximum = 8857, time = 41191 ms, branches = 5748, failures = 2542, depth = 33, Relocate<1>, neighbors = 3380310, filtered neighbors = 999, accepted neighbors = 999, memory used = 206.64 MB, limit = 100%)
# I0000 00:00:1717654003.644822   94576 search.cc:285] Finished search tree (time = 41191 ms, branches = 5748, failures = 2571, neighbors = 3380310, filtered neighbors = 999, accepted neigbors = 999, memory used = 206.64 MB)
# I0000 00:00:1717654003.644903   94576 search.cc:285] End search (time = 41191 ms, branches = 5748, failures = 2571, memory used = 206.64 MB, speed = 139 branches/s)

# %% [markdown]
# # 여기는 수정 중이라 무시

# %%
N = 650//10
M  = 550//10

# 그리드 생성
x = np.linspace(0, N, N*10)
y = np.linspace(0, M, M*10)
x, y = np.meshgrid(x, y)
z = terraced_field_with_noise(x, y, 400, 400)

# 플롯 설정
fig = plt.figure(figsize=(15, 10))  # 여기서 그래프의 크기를 12x8 인치로 설정합니다.
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='terrain', edgecolor='none', alpha = 0.8)

# 축 레이블 설정
ax.set_xlabel('X Coordinates')
ax.set_ylabel('Y Coordinates')
ax.set_zlabel('Elevation')

# 그래프를 45도 회전
ax.view_init(elev=30, azim=-150)  # elev는 30도로 설정, azim은 45도로 설정

# 점 찍기
ax.scatter(points["x"], points["y"], points["z"], color='r', s=1)  # s는 점의 크기

# for route in routes:
#     rx = []
#     ry = []
#     rz = []
#     for node in route:
#         loc = nodes.iloc[node]
#         rx.append(loc['x'])
#         ry.append(loc['y'])
#         rz.append(loc['z'])
#     ax.plot(rx,ry,rz,marker='o')

# 표시
plt.show()

# %%
N = 650//10
M  = 550//10

# 그리드 생성
x = np.linspace(0, N, N*10)
y = np.linspace(0, M, M*10)
x, y = np.meshgrid(x, y)
z = terraced_field_with_noise(x, y, 400, 400)

# 플롯 설정
fig = plt.figure(figsize=(15, 10))  # 여기서 그래프의 크기를 12x8 인치로 설정합니다.
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='terrain', edgecolor='none', alpha = 0.8)

# 축 레이블 설정
ax.set_xlabel('X Coordinates')
ax.set_ylabel('Y Coordinates')
ax.set_zlabel('Elevation')

# 그래프를 45도 회전
ax.view_init(elev=30, azim=-150)  # elev는 30도로 설정, azim은 45도로 설정

# 점 찍기
ax.scatter(points["x"], points["y"], points["z"], color='r', s=1)  # s는 점의 크기

# for route in routes:
#     rx = []
#     ry = []
#     rz = []
#     for node in route:
#         loc = nodes.iloc[node]
#         rx.append(loc['x'])
#         ry.append(loc['y'])
#         rz.append(loc['z'])
#     ax.plot(rx,ry,rz,marker='o')

# 표시
plt.show()
